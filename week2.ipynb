# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdul3ati/PCVK_Genap_20-21/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv 
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/cat01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/cat01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices= np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
imgFigSize = cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(imgFigSize)

# %%
img_g = img
img_g[:,:,0] = 0
img_g[:,:,2] = 0
plt.imshow(img_g)

# %%
croppedImg = img[10:100, 10:100]
croppedImg[:,:,0] = 0
croppedImg[:,:,2] = 0
plt.imshow(croppedImg)

# %%
croppedImg = img[5:30,0:500]
croppedImg[:,:,0] = 0
croppedImg[:,:,2] = 0
plt.imshow(croppedImg)

# %%
imageWithRectangle = cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(10,10))
 

cv.rectangle(imageWithRectangle, pt1=(50,200), pt2=(100,100), color=(0,200,20), thickness = 5)
cv.rectangle(imageWithRectangle, pt1=(20,20), pt2=(50,50), color=(0,255,255), thickness = -5)
cv.rectangle(imageWithRectangle, pt1=(200,200), pt2=(250,350), color=(255,0,0), thickness = 5)
cv.rectangle(imageWithRectangle, pt1=(350,350), pt2=(400,200), color=(255,0,0), thickness = 5)
cv.rectangle(imageWithRectangle, pt1=(500,150), pt2=(600,100), color=(255,255,0),thickness= 5)
plt.imshow(imageWithRectangle)

# %%
flippedImg = cv.flip(imageWithRectangle, 0)
plt.imshow(flippedImg)

# %%
img_0= cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img_0,pt1=(500,250),pt2=(250,50),color=(255,255,255),thickness=3)
cv.circle(img_0,center=(400,170),radius=100,color=(255,0,0),thickness=3)
plt.imshow(img_0)

# %%
img_12=cv.cvtColor(img, cv.COLOR_BGR2RGB)
font = cv.FONT_HERSHEY_SIMPLEX
cv.rectangle(img_12,pt1=(100,600),pt2=(5,500),color=(0,0,255),thickness=3),
cv.putText(img_12,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA),
plt.imshow(img_12)
